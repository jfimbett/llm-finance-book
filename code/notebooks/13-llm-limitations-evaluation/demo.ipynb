# %% [markdown]
# # Chapter 13: LLM Limitations and Evaluation Rigor in Finance
#
# This notebook demonstrates the key concepts from Chapter 13.

# %%
# Setup
import numpy as np
import pandas as pd
print("Chapter 13 demo notebook")
