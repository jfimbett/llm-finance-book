# %% [markdown]
# # Chapter 4 — LLM Agents and Finance Applications
#
# This notebook provides demonstration code for Chapter 4 of *Large Language Models in Finance*.
#
# **Topics covered:**
# - Building a ReAct agent loop with tool use
# - Custom tool registration: financial data retrieval, calculator, web search
# - RAG pipeline for SEC 10-K filings using FAISS
# - Multi-agent orchestration with LangChain
# - Prompt injection defence and human-in-the-loop checkpoints
#
# [Placeholder — fill in with demonstration code when drafting the chapter]
