# %% [markdown]
# # Chapter 10: Portfolio Optimization and Quantitative Trading
#
# This notebook demonstrates the key concepts from Chapter 10.

# %%
# Setup
import numpy as np
import pandas as pd
print("Chapter 10 demo notebook")
