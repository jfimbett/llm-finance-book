# %% [markdown]
# # Chapter 15 — LLMs and Privacy: Local Deployments and Text De-identification
#
# This notebook accompanies Chapter 15 of *Large Language Models in Finance*.
# It demonstrates the core techniques covered in the chapter:
#
# 1. Identifying and masking PII in financial text using spaCy NER
# 2. Running a local open-weight LLM (Llama/Mistral via `llama-cpp-python` or Ollama)
# 3. Building a simple differential-privacy gradient-noise wrapper
# 4. Constructing a privacy-aware RAG pipeline with audit logging
#
# **Prerequisites:** `spacy`, `transformers`, `datasets`, `opacus` (for DP-SGD), `langchain`
