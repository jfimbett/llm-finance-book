# %% [markdown]
# # Chapter 16: Artificial Intelligence, Machine Learning, and Text in Finance
#
# This notebook provides a demonstration companion to Chapter 16.
# It illustrates key concepts including the AI–ML hierarchy, financial text sources,
# and a basic comparison of bag-of-words vs. transformer-based approaches on
# financial text.
#
# > **Status:** Placeholder — content to be developed alongside `/draft-chapter`.
