# %% [markdown]
# # Demo — Lecture 1: Introduction to LLMs in Finance
#
# This notebook accompanies Lecture 1 and Chapter 1.
#
# **Topics covered:**
# - Classical text representations (Bag-of-Words, TF-IDF)
# - Word embeddings with Word2Vec / GloVe
# - PCA visualisation of financial vocabulary
# - Document-level aggregation
# - Calling an LLM via API (OpenAI / Anthropic)
#
# Invoke `/draft-code` to generate the full implementation.

# %%
# Imports — TODO: fill in via /draft-code
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Section 3: Classical Text Representations
#
# [Placeholder]

# %% [markdown]
# ## Section 4: Word Embeddings & PCA Case Study
#
# [Placeholder — produces the PCA figure used in slides.tex]

# %% [markdown]
# ## Section 9: Working with LLMs via API
#
# [Placeholder — live API call demo]
