# %% [markdown]
# # Chapter 09: Financial NLP and Sentiment Analysis
#
# This notebook demonstrates the key concepts from Chapter 09.

# %%
# Setup
import numpy as np
import pandas as pd
print("Chapter 09 demo notebook")
