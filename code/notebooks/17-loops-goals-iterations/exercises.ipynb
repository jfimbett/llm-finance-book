# %% [markdown]
# # Chapter 17 — Exercises: Loops, Goals, and Iterations
#
# Exercise notebook. Companion to `course/lectures/17-loops-goals-iterations/exercises.md`.
#
# Planned exercises:
# - **[B]** Turn a vague goal into a concrete, checkable, decomposable control object (success criterion, stopping rule, goal file).
# - **[I]** Build the derivative-free root-finding loop for `f(x) = x**3 - x - 2` with a tolerance hook (`|f(x)| < 0.001`) and produce the iteration trace.
# - **[A]** Design the credit-risk agent ensemble, its skills, and its hooks; argue why the task needs many feedback-driven iterations.
#
# [Placeholder] To be expanded by `/draft-code`.
