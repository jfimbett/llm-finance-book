# %% [markdown]
# # Demo — Lecture 1: Introduction
#
# This notebook accompanies Lecture 1 and Chapter 1.
# Invoke `/draft-code` to generate the full demo.

# %%
# Imports
import numpy as np
import matplotlib.pyplot as plt

# TODO: invoke /draft-code to fill in this notebook
