# %% [markdown]
# # Chapter 2: Large Language Models — Architecture and Practice
#
# This notebook accompanies Chapter 2 of *Large Language Models in Finance*.
# It demonstrates temperature sampling, structured generation, and a minimal RAG pipeline.
