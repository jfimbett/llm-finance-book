# %% [markdown]
# # Chapter 12: Explainability and XAI in Finance
#
# This notebook demonstrates the key concepts from Chapter 12.

# %%
# Setup
import numpy as np
import pandas as pd
print("Chapter 12 demo notebook")
